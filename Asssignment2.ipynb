# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Untitled spreadsheet - Sheet1 (3).csv')

# %%
df1=df
df2=df1
df3=df
df4=df

# %%
df.isnull()
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False           True            False           False
# 5        False          False          False             True           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False           True          False            False           False
# 10        True          False          False             True           False
# 11       False          False          False            False           False
# 12       False          False          False            False           False
# 13       False          False          False            False           False
# 14       False          False           True            False           False
# 15        True          False          False             True           False
# 16       False          False          False            False            True
# 17       False          False          False            False           False
# 18       False          False          False            False           False
# 19       False           True          False            False           False
# 20       False          False          False            False           False
# 21       False          False          False            False           False
# 22       False          False          False            False           False
# 23       False          False          False            False           False
# 24       False          False          False             True           False
# 25       False          False          False            False           False
# 26       False          False          False            False           False
# 27       False          False          False            False           False
# 28       False          False          False            False           False
#
#     placement offer count  Gender
# 0                   False   False
# 1                   False   False
# 2                   False   False
# 3                   False   False
# 4                   False   False
# 5                   False   False
# 6                   False   False
# 7                   False   False
# 8                   False   False
# 9                   False   False
# 10                  False   False
# 11                  False   False
# 12                  False   False
# 13                  False   False
# 14                  False   False
# 15                  False   False
# 16                  False   False
# 17                  False   False
# 18                  False   False
# 19                  False   False
# 20                  False   False
# 21                  False   False
# 22                  False   False
# 23                  False   False
# 24                  False   False
# 25                  False   False
# 26                  False   False
# 27                  False   False
# 28                  False   False

# %%
df.isnull().sum()
# Out:
# math score               2
# reading score            2
# writing score            2
# placement score          4
# club join year           1
# placement offer count    0
# Gender                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['math score', 'reading score', 'writing score', 'placement score',
#        'club join year', 'placement offer count', 'Gender'],
#       dtype='object')

# %%
df.isnull().any()
# Out:
# math score                True
# reading score             True
# writing score             True
# placement score           True
# club join year            True
# placement offer count    False
# Gender                   False
# dtype: bool

# %%
pd.isnull(df['math score']).sum()
# Out:
# 2

# %%
df.notnull()
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True          False             True            True
# 5         True           True           True            False            True
# 6         True           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True          False           True             True            True
# 10       False           True           True            False            True
# 11        True           True           True             True            True
# 12        True           True           True             True            True
# 13        True           True           True             True            True
# 14        True           True          False             True            True
# 15       False           True           True            False            True
# 16        True           True           True             True           False
# 17        True           True           True             True            True
# 18        True           True           True             True            True
# 19        True          False           True             True            True
# 20        True           True           True             True            True
# 21        True           True           True             True            True
# 22        True           True           True             True            True
# 23        True           True           True             True            True
# 24        True           True           True            False            True
# 25        True           True           True             True            True
# 26        True           True           True             True            True
# 27        True           True           True             True            True
# 28        True           True           True             True            True
#
#     placement offer count  Gender
# 0                    True    True
# 1                    True    True
# 2                    True    True
# 3                    True    True
# 4                    True    True
# 5                    True    True
# 6                    True    True
# 7                    True    True
# 8                    True    True
# 9                    True    True
# 10                   True    True
# 11                   True    True
# 12                   True    True
# 13                   True    True
# 14                   True    True
# 15                   True    True
# 16                   True    True
# 17                   True    True
# 18                   True    True
# 19                   True    True
# 20                   True    True
# 21                   True    True
# 22                   True    True
# 23                   True    True
# 24                   True    True
# 25                   True    True
# 26                   True    True
# 27                   True    True
# 28                   True    True

# %%
df.notnull().sum()
# Out:
# math score               27
# reading score            27
# writing score            27
# placement score          25
# club join year           28
# placement offer count    29
# Gender                   29
# dtype: int64

# %%
df.head()
df1=df

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])
df
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         63.0           84.0           64.0             84.0          2020.0
# 1         71.0           80.0           76.0             86.0          2018.0
# 2         64.0           81.0           66.0             81.0          2020.0
# 3         71.0           85.0           77.0             91.0          2018.0
# 4         68.0           86.0            NaN             92.0          2021.0
# 5         79.0           86.0           61.0              NaN          2019.0
# 6         75.0           79.0           66.0             76.0          2020.0
# 7         71.0           79.0           66.0             95.0          2019.0
# 8         66.0           88.0           66.0             88.0          2020.0
# 9         70.0            NaN           61.0             87.0          2021.0
# 10         NaN           80.0           65.0              NaN          2021.0
# 11        76.0           84.0           73.0             92.0          2020.0
# 12        74.0           79.0           79.0             98.0          2019.0
# 13        78.0           78.0           78.0             88.0          2018.0
# 14        80.0           80.0            NaN             90.0          2020.0
# 15         NaN           98.0           98.0              NaN          2021.0
# 16        89.0           89.0           89.0             66.0             NaN
# 17        67.0           67.0           67.0             67.0          2018.0
# 18        68.0           68.0           68.0             88.0          2019.0
# 19        79.0            NaN           79.0             87.0          2020.0
# 20        80.0           80.0           80.0             78.0          2021.0
# 21        90.0           90.0           90.0             89.0          2019.0
# 22        88.0           88.0           88.0             89.0          2018.0
# 23        77.0           77.0           77.0             88.0          2019.0
# 24        67.0           67.0           67.0              NaN          2020.0
# 25        76.0           76.0           76.0             66.0          2021.0
# 26        97.0           97.0           97.0             65.0          2018.0
# 27        79.0           79.0           79.0             64.0          2020.0
# 28        88.0           88.0           88.0             74.0          2021.0
#
#     placement offer count  Gender
# 0                       2       1
# 1                       3       0
# 2                       2       1
# 3                       3       0
# 4                       3       1
# 5                       1       0
# 6                       2       1
# 7                       3       0
# 8                       3       1
# 9                       3       0
# 10                      1       1
# 11                      3       0
# 12                      3       1
# 13                      3       0
# 14                      3       1
# 15                      2       0
# 16                      3       1
# 17                      3       0
# 18                      2       1
# 19                      3       0
# 20                      3       1
# 21                      2       0
# 22                      3       1
# 23                      2       0
# 24                      3       1
# 25                      2       0
# 26                      3       1
# 27                      3       0
# 28                      3       1

# %%
df.columns
# Out:
# Index(['math score', 'reading score', 'writing score', 'placement score',
#        'club join year', 'placement offer count', 'Gender'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# math score               2
# reading score            2
# writing score            2
# placement score          4
# club join year           1
# placement offer count    0
# Gender                   0
# dtype: int64

# %%
df.describe()
# Out:
#        math score  reading score  writing score  placement score  \
# count   27.000000      27.000000      27.000000         25.00000
# mean    75.962963      81.962963      75.592593         82.76000
# std      8.719922       7.663507      10.692410         10.27651
# min     63.000000      67.000000      61.000000         64.00000
# 25%     69.000000      79.000000      66.000000         76.00000
# 50%     76.000000      80.000000      76.000000         87.00000
# 75%     79.500000      87.000000      79.500000         89.00000
# max     97.000000      98.000000      98.000000         98.00000
#
#        club join year  placement offer count     Gender
# count       28.000000              29.000000  29.000000
# mean      2019.607143               2.586207   0.517241
# std          1.100144               0.627765   0.508548
# min       2018.000000               1.000000   0.000000
# 25%       2019.000000               2.000000   0.000000
# 50%       2020.000000               3.000000   1.000000
# 75%       2020.250000               3.000000   1.000000
# max       2021.000000               3.000000   1.000000

# %%
df['reading score']
# Out:
# 0     84.0
# 1     80.0
# 2     81.0
# 3     85.0
# 4     86.0
# 5     86.0
# 6     79.0
# 7     79.0
# 8     88.0
# 9      NaN
# 10    80.0
# 11    84.0
# 12    79.0
# 13    78.0
# 14    80.0
# 15    98.0
# 16    89.0
# 17    67.0
# 18    68.0
# 19     NaN
# 20    80.0
# 21    90.0
# 22    88.0
# 23    77.0
# 24    67.0
# 25    76.0
# 26    97.0
# 27    79.0
# 28    88.0
# Name: reading score, dtype: float64

# %%
df[df['reading score'].isnull()].index.tolist()
# Out:
# [9, 19]

# %%
df['reading score']=df['reading score'].fillna(60)

# %%
df['reading score']
# Out:
# 0     84.0
# 1     80.0
# 2     81.0
# 3     85.0
# 4     86.0
# 5     86.0
# 6     79.0
# 7     79.0
# 8     88.0
# 9     60.0
# 10    80.0
# 11    84.0
# 12    79.0
# 13    78.0
# 14    80.0
# 15    98.0
# 16    89.0
# 17    67.0
# 18    68.0
# 19    60.0
# 20    80.0
# 21    90.0
# 22    88.0
# 23    77.0
# 24    67.0
# 25    76.0
# 26    97.0
# 27    79.0
# 28    88.0
# Name: reading score, dtype: float64

# %%
df['reading score'].notnull().sum()
# Out:
# 29

# %%
df[df['math score'].isnull()].index.tolist()
# Out:
# [10, 15]

# %%
df['math score']=df['math score'].fillna(df['math score'].mean())

# %%
df['math score'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# math score               0
# reading score            0
# writing score            2
# placement score          4
# club join year           1
# placement offer count    0
# Gender                   0
# dtype: int64

# %%
df[df['writing score'].isnull()].index.tolist()
# Out:
# [4, 14]

# %%
df['writing score']=df['writing score'].fillna(df['writing score'].median())

# %%
df['writing score'].isnull().sum()
# Out:
# 0

# %%
df2.head()
# Out:
#    math score  reading score  writing score  placement score  club join year  \
# 0        63.0           84.0           64.0             84.0          2020.0
# 1        71.0           80.0           76.0             86.0          2018.0
# 2        64.0           81.0           66.0             81.0          2020.0
# 3        71.0           85.0           77.0             91.0          2018.0
# 4        68.0           86.0           76.0             92.0          2021.0
#
#    placement offer count  Gender
# 0                      2       1
# 1                      3       0
# 2                      2       1
# 3                      3       0
# 4                      3       1

# %%
import numpy as np

# %%
df.isnull().sum()
# Out:
# math score               0
# reading score            0
# writing score            0
# placement score          4
# club join year           1
# placement offer count    0
# Gender                   0
# dtype: int64

# %%
df[df['math score'].isnull()].index.tolist()
# Out:
# []

# %%
df.replace(to_replace=np.nan, value = 80)
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0    63.000000           84.0           64.0             84.0          2020.0
# 1    71.000000           80.0           76.0             86.0          2018.0
# 2    64.000000           81.0           66.0             81.0          2020.0
# 3    71.000000           85.0           77.0             91.0          2018.0
# 4    68.000000           86.0           76.0             92.0          2021.0
# 5    79.000000           86.0           61.0             80.0          2019.0
# 6    75.000000           79.0           66.0             76.0          2020.0
# 7    71.000000           79.0           66.0             95.0          2019.0
# 8    66.000000           88.0           66.0             88.0          2020.0
# 9    70.000000           60.0           61.0             87.0          2021.0
# 10   75.962963           80.0           65.0             80.0          2021.0
# 11   76.000000           84.0           73.0             92.0          2020.0
# 12   74.000000           79.0           79.0             98.0          2019.0
# 13   78.000000           78.0           78.0             88.0          2018.0
# 14   80.000000           80.0           76.0             90.0          2020.0
# 15   75.962963           98.0           98.0             80.0          2021.0
# 16   89.000000           89.0           89.0             66.0            80.0
# 17   67.000000           67.0           67.0             67.0          2018.0
# 18   68.000000           68.0           68.0             88.0          2019.0
# 19   79.000000           60.0           79.0             87.0          2020.0
# 20   80.000000           80.0           80.0             78.0          2021.0
# 21   90.000000           90.0           90.0             89.0          2019.0
# 22   88.000000           88.0           88.0             89.0          2018.0
# 23   77.000000           77.0           77.0             88.0          2019.0
# 24   67.000000           67.0           67.0             80.0          2020.0
# 25   76.000000           76.0           76.0             66.0          2021.0
# 26   97.000000           97.0           97.0             65.0          2018.0
# 27   79.000000           79.0           79.0             64.0          2020.0
# 28   88.000000           88.0           88.0             74.0          2021.0
#
#     placement offer count  Gender
# 0                       2       1
# 1                       3       0
# 2                       2       1
# 3                       3       0
# 4                       3       1
# 5                       1       0
# 6                       2       1
# 7                       3       0
# 8                       3       1
# 9                       3       0
# 10                      1       1
# 11                      3       0
# 12                      3       1
# 13                      3       0
# 14                      3       1
# 15                      2       0
# 16                      3       1
# 17                      3       0
# 18                      2       1
# 19                      3       0
# 20                      3       1
# 21                      2       0
# 22                      3       1
# 23                      2       0
# 24                      3       1
# 25                      2       0
# 26                      3       1
# 27                      3       0
# 28                      3       1

# %%
df2.isnull().sum()
# Out:
# math score               0
# reading score            0
# writing score            0
# placement score          4
# club join year           1
# placement offer count    0
# Gender                   0
# dtype: int64

# %% [markdown]
# #.Deleting null values using dropna()method

# %%
df3.isnull().sum()
# Out:
# math score               0
# reading score            0
# writing score            0
# placement score          4
# club join year           1
# placement offer count    0
# Gender                   0
# dtype: int64

# %%
df3[df3['math score'].isnull()].index.tolist()
# Out:
# []

# %%
df3[df3['reading score'].isnull()].index.tolist()
# Out:
# []

# %%
#to drop rows with at least 1 null value
df3.dropna()
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         63.0           84.0           64.0             84.0          2020.0
# 1         71.0           80.0           76.0             86.0          2018.0
# 2         64.0           81.0           66.0             81.0          2020.0
# 3         71.0           85.0           77.0             91.0          2018.0
# 4         68.0           86.0           76.0             92.0          2021.0
# 6         75.0           79.0           66.0             76.0          2020.0
# 7         71.0           79.0           66.0             95.0          2019.0
# 8         66.0           88.0           66.0             88.0          2020.0
# 9         70.0           60.0           61.0             87.0          2021.0
# 11        76.0           84.0           73.0             92.0          2020.0
# 12        74.0           79.0           79.0             98.0          2019.0
# 13        78.0           78.0           78.0             88.0          2018.0
# 14        80.0           80.0           76.0             90.0          2020.0
# 17        67.0           67.0           67.0             67.0          2018.0
# 18        68.0           68.0           68.0             88.0          2019.0
# 19        79.0           60.0           79.0             87.0          2020.0
# 20        80.0           80.0           80.0             78.0          2021.0
# 21        90.0           90.0           90.0             89.0          2019.0
# 22        88.0           88.0           88.0             89.0          2018.0
# 23        77.0           77.0           77.0             88.0          2019.0
# 25        76.0           76.0           76.0             66.0          2021.0
# 26        97.0           97.0           97.0             65.0          2018.0
# 27        79.0           79.0           79.0             64.0          2020.0
# 28        88.0           88.0           88.0             74.0          2021.0
#
#     placement offer count  Gender
# 0                       2       1
# 1                       3       0
# 2                       2       1
# 3                       3       0
# 4                       3       1
# 6                       2       1
# 7                       3       0
# 8                       3       1
# 9                       3       0
# 11                      3       0
# 12                      3       1
# 13                      3       0
# 14                      3       1
# 17                      3       0
# 18                      2       1
# 19                      3       0
# 20                      3       1
# 21                      2       0
# 22                      3       1
# 23                      2       0
# 25                      2       0
# 26                      3       1
# 27                      3       0
# 28                      3       1

# %%
#To Drop columns with at lest 1 null value
df4.dropna(axis=1)
# Out:
#     math score  reading score  writing score  placement offer count  Gender
# 0    63.000000           84.0           64.0                      2       1
# 1    71.000000           80.0           76.0                      3       0
# 2    64.000000           81.0           66.0                      2       1
# 3    71.000000           85.0           77.0                      3       0
# 4    68.000000           86.0           76.0                      3       1
# 5    79.000000           86.0           61.0                      1       0
# 6    75.000000           79.0           66.0                      2       1
# 7    71.000000           79.0           66.0                      3       0
# 8    66.000000           88.0           66.0                      3       1
# 9    70.000000           60.0           61.0                      3       0
# 10   75.962963           80.0           65.0                      1       1
# 11   76.000000           84.0           73.0                      3       0
# 12   74.000000           79.0           79.0                      3       1
# 13   78.000000           78.0           78.0                      3       0
# 14   80.000000           80.0           76.0                      3       1
# 15   75.962963           98.0           98.0                      2       0
# 16   89.000000           89.0           89.0                      3       1
# 17   67.000000           67.0           67.0                      3       0
# 18   68.000000           68.0           68.0                      2       1
# 19   79.000000           60.0           79.0                      3       0
# 20   80.000000           80.0           80.0                      3       1
# 21   90.000000           90.0           90.0                      2       0
# 22   88.000000           88.0           88.0                      3       1
# 23   77.000000           77.0           77.0                      2       0
# 24   67.000000           67.0           67.0                      3       1
# 25   76.000000           76.0           76.0                      2       0
# 26   97.000000           97.0           97.0                      3       1
# 27   79.000000           79.0           79.0                      3       0
# 28   88.000000           88.0           88.0                      3       1

# %% [markdown]
# #Handling outliers
#
#  **##1.Detecting outliers using Boxplot:**
#  It Captures the summary of the data effectively and efficiently with only a simplpe box and whiskers Boxplot summarizes sample data using 25th , 50yh and 75thpercentile One can just get insights(quarties,median , and outliers)
# into the dataset by just looking at its boxplot

# %%
df.columns
# Out:
# Index(['math score', 'reading score', 'writing score', 'placement score',
#        'club join year', 'placement offer count', 'Gender'],
#       dtype='object')

# %%
col=['math score', 'reading score', 'writing score', 'placement score',
       'club join year', 'placement offer count', 'Gender']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(18,7))
df.boxplot(col)
# Out:
# <Axes: >

# %%
for coloumn in df :
  plt.figure()
  df.boxplot([coloumn])

# %%
import seaborn as sns

# %%
for coloumn in df :
      plt.figure(figsize=(7,5))
      sns.boxplot(data=df,y=coloumn)

# %%
print(np.where(df['math score']>80))
# Out:
# (array([16, 21, 22, 26, 28]),)

# %%
print(np.where(df['math score']>90))
# Out:
# (array([26]),)

# %%
print(np.where(df['math score']<40))
# Out:
# (array([], dtype=int64),)

# %% [markdown]
#  **##.Detecting outlier using Scatterplot:**

# %%
#ax = plt.subplots(figsize=(18,10))
plt.scatter(df['math score'],df['placement offer count'])
plt.show()

# %%
df.columns
# Out:
# Index(['math score', 'reading score', 'writing score', 'placement score',
#        'club join year', 'placement offer count', 'Gender'],
#       dtype='object')

# %%
plt.scatter(df['placement score'],df['placement offer count'],c='yellow',linewidths=2,marker='.',edgecolor='blue',s=50)
plt.xlabel=("placement score")
plt.ylabel=("placement offer count")
plt.show()

# %%
plt.scatter(x=df['math score'],y=df['placement score'],c='yellow',linewidths=2,marker='^',edgecolor='green',s=80)
plt.show()

# %%
plt.figure()
df.plot.scatter(x = 'placement score', y = 'placement offer count',c = 'Gender',alpha = 0.4,cmap = plt.get_cmap('jet'),colorbar = 'red')
#plt.savefig('scatter plot.png')
#plt.tight_layout()
plt.show()

# %% [markdown]
# ##Detecting outliers using Z-score:

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df['math score']))
z
# Out:
# 0     1.570016
# 1     0.601092
# 2     1.448900
# 3     0.601092
# 4     0.964438
# 5     0.367832
# 6     0.116630
# 7     0.601092
# 8     1.206669
# 9     0.722207
# 10    0.000000
# 11    0.004486
# 12    0.237745
# 13    0.246717
# 14    0.488948
# 15    0.000000
# 16    1.578987
# 17    1.085554
# 18    0.964438
# 19    0.367832
# 20    0.488948
# 21    1.700103
# 22    1.457872
# 23    0.125601
# 24    1.085554
# 25    0.004486
# 26    2.547911
# 27    0.367832
# 28    1.457872
# Name: math score, dtype: float64

# %%
threshold = 1.8
sample_outliers = np.where(z>threshold)
sample_outliers
# Out:
# (array([26]),)

# %%
df['math score']
# Out:
# 0     63.000000
# 1     71.000000
# 2     64.000000
# 3     71.000000
# 4     68.000000
# 5     79.000000
# 6     75.000000
# 7     71.000000
# 8     66.000000
# 9     70.000000
# 10    75.962963
# 11    76.000000
# 12    74.000000
# 13    78.000000
# 14    80.000000
# 15    75.962963
# 16    89.000000
# 17    67.000000
# 18    68.000000
# 19    79.000000
# 20    80.000000
# 21    90.000000
# 22    88.000000
# 23    77.000000
# 24    67.000000
# 25    76.000000
# 26    97.000000
# 27    79.000000
# 28    88.000000
# Name: math score, dtype: float64

# %% [markdown]
# ##4. Detecting outliers using Inter Quantile Range(IQR):

# %%
sorted_rscore = sorted(df['reading score'])
sorted_rscore
# Out:
# [60.0,
#  60.0,
#  67.0,
#  67.0,
#  68.0,
#  76.0,
#  77.0,
#  78.0,
#  79.0,
#  79.0,
#  79.0,
#  79.0,
#  80.0,
#  80.0,
#  80.0,
#  80.0,
#  81.0,
#  84.0,
#  84.0,
#  85.0,
#  86.0,
#  86.0,
#  88.0,
#  88.0,
#  88.0,
#  89.0,
#  90.0,
#  97.0,
#  98.0]

# %%
#calculate and print Quartile 1 and Quartile 3
q1 = np.percentile(sorted_rscore,25)
q3 = np.percentile(sorted_rscore,75)

# %%
IQR = q3-q1
IQR
# Out:
# 8.0

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound,upr_bound)
# Out:
# 66.0 98.0

# %%
#print outliers
r_outliers =[]
for i in sorted_rscore:
  if(i<lwr_bound or i>upr_bound):
    r_outliers.append(i)
    print(r_outliers)
# Out:
# [60.0]
# [60.0, 60.0]

# %%
df['reading score']
# Out:
# 0     84.0
# 1     80.0
# 2     81.0
# 3     85.0
# 4     86.0
# 5     86.0
# 6     79.0
# 7     79.0
# 8     88.0
# 9     60.0
# 10    80.0
# 11    84.0
# 12    79.0
# 13    78.0
# 14    80.0
# 15    98.0
# 16    89.0
# 17    67.0
# 18    68.0
# 19    60.0
# 20    80.0
# 21    90.0
# 22    88.0
# 23    77.0
# 24    67.0
# 25    76.0
# 26    97.0
# 27    79.0
# 28    88.0
# Name: reading score, dtype: float64

# %% [markdown]
# ##Handling of Outliers:

# %% [markdown]
# ##1. Trimming/Removing the Outlier

# %%
new_df=df.copy()
for i in sample_outliers:
  new_df.drop(i,inplace=True)
  new_df

# %% [markdown]
# ##2. Quantile based flooring and capping

# %%
df_stud=df.copy()

# %%
df_stud
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0    63.000000           84.0           64.0             84.0          2020.0
# 1    71.000000           80.0           76.0             86.0          2018.0
# 2    64.000000           81.0           66.0             81.0          2020.0
# 3    71.000000           85.0           77.0             91.0          2018.0
# 4    68.000000           86.0           76.0             92.0          2021.0
# 5    79.000000           86.0           61.0              NaN          2019.0
# 6    75.000000           79.0           66.0             76.0          2020.0
# 7    71.000000           79.0           66.0             95.0          2019.0
# 8    66.000000           88.0           66.0             88.0          2020.0
# 9    70.000000           60.0           61.0             87.0          2021.0
# 10   75.962963           80.0           65.0              NaN          2021.0
# 11   76.000000           84.0           73.0             92.0          2020.0
# 12   74.000000           79.0           79.0             98.0          2019.0
# 13   78.000000           78.0           78.0             88.0          2018.0
# 14   80.000000           80.0           76.0             90.0          2020.0
# 15   75.962963           98.0           98.0              NaN          2021.0
# 16   89.000000           89.0           89.0             66.0             NaN
# 17   67.000000           67.0           67.0             67.0          2018.0
# 18   68.000000           68.0           68.0             88.0          2019.0
# 19   79.000000           60.0           79.0             87.0          2020.0
# 20   80.000000           80.0           80.0             78.0          2021.0
# 21   90.000000           90.0           90.0             89.0          2019.0
# 22   88.000000           88.0           88.0             89.0          2018.0
# 23   77.000000           77.0           77.0             88.0          2019.0
# 24   67.000000           67.0           67.0              NaN          2020.0
# 25   76.000000           76.0           76.0             66.0          2021.0
# 26   97.000000           97.0           97.0             65.0          2018.0
# 27   79.000000           79.0           79.0             64.0          2020.0
# 28   88.000000           88.0           88.0             74.0          2021.0
#
#     placement offer count  Gender
# 0                       2       1
# 1                       3       0
# 2                       2       1
# 3                       3       0
# 4                       3       1
# 5                       1       0
# 6                       2       1
# 7                       3       0
# 8                       3       1
# 9                       3       0
# 10                      1       1
# 11                      3       0
# 12                      3       1
# 13                      3       0
# 14                      3       1
# 15                      2       0
# 16                      3       1
# 17                      3       0
# 18                      2       1
# 19                      3       0
# 20                      3       1
# 21                      2       0
# 22                      3       1
# 23                      2       0
# 24                      3       1
# 25                      2       0
# 26                      3       1
# 27                      3       0
# 28                      3       1

# %%
print(df_stud['math score'].quantile(0.10))
print(df_stud['math score'].quantile(0.90))
# Out:
# 66.8
# 88.2

# %%
df_std1=df_stud.copy()
a = np.where(df_stud['math score']<62.0,62.0,df_stud['math score'])
b = np.where(df_stud['math score']<62.0,62.0,df_stud['math score'])

# %%
print("a=",a)
print("b=",b)
# Out:
# a= [63.         71.         64.         71.         68.         79.
#  75.         71.         66.         70.         75.96296296 76.
#  74.         78.         80.         75.96296296 89.         67.
#  68.         79.         80.         90.         88.         77.
#  67.         76.         97.         79.         88.        ]
# b= [63.         71.         64.         71.         68.         79.
#  75.         71.         66.         70.         75.96296296 76.
#  74.         78.         80.         75.96296296 89.         67.
#  68.         79.         80.         90.         88.         77.
#  67.         76.         97.         79.         88.        ]

# %%
df_stud.insert(1,"new_math<62",a,True)
df_stud.insert(1,"new_math>79.1",b,True)

# %% [markdown]
# ##3.Imputing median value

# %%
#col = ['reading score']
plt.boxplot(df['reading score'])
plt.show()

# %%
median=np.median(sorted_rscore)
median
# Out:
# 80.0

# %%
new_df=df.copy()
new_df2=new_df.copy()
new_df
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0    63.000000           84.0           64.0             84.0          2020.0
# 1    71.000000           80.0           76.0             86.0          2018.0
# 2    64.000000           81.0           66.0             81.0          2020.0
# 3    71.000000           85.0           77.0             91.0          2018.0
# 4    68.000000           86.0           76.0             92.0          2021.0
# 5    79.000000           86.0           61.0              NaN          2019.0
# 6    75.000000           79.0           66.0             76.0          2020.0
# 7    71.000000           79.0           66.0             95.0          2019.0
# 8    66.000000           88.0           66.0             88.0          2020.0
# 9    70.000000           60.0           61.0             87.0          2021.0
# 10   75.962963           80.0           65.0              NaN          2021.0
# 11   76.000000           84.0           73.0             92.0          2020.0
# 12   74.000000           79.0           79.0             98.0          2019.0
# 13   78.000000           78.0           78.0             88.0          2018.0
# 14   80.000000           80.0           76.0             90.0          2020.0
# 15   75.962963           98.0           98.0              NaN          2021.0
# 16   89.000000           89.0           89.0             66.0             NaN
# 17   67.000000           67.0           67.0             67.0          2018.0
# 18   68.000000           68.0           68.0             88.0          2019.0
# 19   79.000000           60.0           79.0             87.0          2020.0
# 20   80.000000           80.0           80.0             78.0          2021.0
# 21   90.000000           90.0           90.0             89.0          2019.0
# 22   88.000000           88.0           88.0             89.0          2018.0
# 23   77.000000           77.0           77.0             88.0          2019.0
# 24   67.000000           67.0           67.0              NaN          2020.0
# 25   76.000000           76.0           76.0             66.0          2021.0
# 26   97.000000           97.0           97.0             65.0          2018.0
# 27   79.000000           79.0           79.0             64.0          2020.0
# 28   88.000000           88.0           88.0             74.0          2021.0
#
#     placement offer count  Gender
# 0                       2       1
# 1                       3       0
# 2                       2       1
# 3                       3       0
# 4                       3       1
# 5                       1       0
# 6                       2       1
# 7                       3       0
# 8                       3       1
# 9                       3       0
# 10                      1       1
# 11                      3       0
# 12                      3       1
# 13                      3       0
# 14                      3       1
# 15                      2       0
# 16                      3       1
# 17                      3       0
# 18                      2       1
# 19                      3       0
# 20                      3       1
# 21                      2       0
# 22                      3       1
# 23                      2       0
# 24                      3       1
# 25                      2       0
# 26                      3       1
# 27                      3       0
# 28                      3       1

# %%
new_df['reading score']=np.where(new_df['reading score']> upr_bound,73.0,new_df['reading score'])

# %%
new_df.insert(2,"old_reading_score",new_df2['reading score'],True)

# %%
new_df
# Out:
#     math score  reading score  old_reading_score  old_reading_score  \
# 0    63.000000           84.0               84.0               84.0
# 1    71.000000           80.0               80.0               80.0
# 2    64.000000           81.0               81.0               81.0
# 3    71.000000           85.0               85.0               85.0
# 4    68.000000           86.0               86.0               86.0
# 5    79.000000           86.0               86.0               86.0
# 6    75.000000           79.0               79.0               79.0
# 7    71.000000           79.0               79.0               79.0
# 8    66.000000           88.0               88.0               88.0
# 9    70.000000           60.0               60.0               60.0
# 10   75.962963           80.0               80.0               80.0
# 11   76.000000           84.0               84.0               84.0
# 12   74.000000           79.0               79.0               79.0
# 13   78.000000           78.0               78.0               78.0
# 14   80.000000           80.0               80.0               80.0
# 15   75.962963           98.0               98.0               98.0
# 16   89.000000           89.0               89.0               89.0
# 17   67.000000           67.0               67.0               67.0
# 18   68.000000           68.0               68.0               68.0
# 19   79.000000           60.0               60.0               60.0
# 20   80.000000           80.0               80.0               80.0
# 21   90.000000           90.0               90.0               90.0
# 22   88.000000           88.0               88.0               88.0
# 23   77.000000           77.0               77.0               77.0
# 24   67.000000           67.0               67.0               67.0
# 25   76.000000           76.0               76.0               76.0
# 26   97.000000           97.0               97.0               97.0
# 27   79.000000           79.0               79.0               79.0
# 28   88.000000           88.0               88.0               88.0
#
#     writing score  placement score  club join year  placement offer count  \
# 0            64.0             84.0          2020.0                      2
# 1            76.0             86.0          2018.0                      3
# 2            66.0             81.0          2020.0                      2
# 3            77.0             91.0          2018.0                      3
# 4            76.0             92.0          2021.0                      3
# 5            61.0              NaN          2019.0                      1
# 6            66.0             76.0          2020.0                      2
# 7            66.0             95.0          2019.0                      3
# 8            66.0             88.0          2020.0                      3
# 9            61.0             87.0          2021.0                      3
# 10           65.0              NaN          2021.0                      1
# 11           73.0             92.0          2020.0                      3
# 12           79.0             98.0          2019.0                      3
# 13           78.0             88.0          2018.0                      3
# 14           76.0             90.0          2020.0                      3
# 15           98.0              NaN          2021.0                      2
# 16           89.0             66.0             NaN                      3
# 17           67.0             67.0          2018.0                      3
# 18           68.0             88.0          2019.0                      2
# 19           79.0             87.0          2020.0                      3
# 20           80.0             78.0          2021.0                      3
# 21           90.0             89.0          2019.0                      2
# 22           88.0             89.0          2018.0                      3
# 23           77.0             88.0          2019.0                      2
# 24           67.0              NaN          2020.0                      3
# 25           76.0             66.0          2021.0                      2
# 26           97.0             65.0          2018.0                      3
# 27           79.0             64.0          2020.0                      3
# 28           88.0             74.0          2021.0                      3
#
#     Gender
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
# 5        0
# 6        1
# 7        0
# 8        1
# 9        0
# 10       1
# 11       0
# 12       1
# 13       0
# 14       1
# 15       0
# 16       1
# 17       0
# 18       1
# 19       0
# 20       1
# 21       0
# 22       1
# 23       0
# 24       1
# 25       0
# 26       1
# 27       0
# 28       1

# %%
plt.boxplot(new_df['reading score'])
plt.show()
